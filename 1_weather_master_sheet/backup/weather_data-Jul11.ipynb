# %%
import pandas as pd
import csv
from collections import OrderedDict
from datetime import datetime

#from collections import OrderedDict

# Read all sheets from the Excel file into a dictionary
xls = pd.read_excel('MASTER_DF_updated_master.xlsx', sheet_name=None)

# View all available sheet names
sheet_names = list(xls.keys())
print("Sheets found:", sheet_names)

# Dictionary to store OrderedDicts for each trial
ordered_data_by_sheet = OrderedDict()

# Access each sheet individually and convert rows to OrderedDict
df_trial1 = xls.get('Trial1')
df_trial2 = xls.get('Trial2')
df_trial3 = xls.get('Trial3')
df_trial4 = xls.get('Trial4')
df_trial5 = xls.get('Trial5')
df_trial6 = xls.get('Trial6')
df_trial7 = xls.get('Trial7')
df_trial8 = xls.get('Trial8')
df_trial9 = xls.get('Trial9')
df_trial10 = xls.get('Trial10')
df_trial11 = xls.get('Trial11')

# Manually list trials you want to convert
trial_dfs = {
    'Trial1': df_trial1,
    'Trial2': df_trial2,
    'Trial3': df_trial3,
    'Trial4': df_trial4,
    'Trial5': df_trial5,
    'Trial6': df_trial6,
    'Trial7': df_trial7,
    'Trial8': df_trial8,
    'Trial9': df_trial9,
    'Trial10': df_trial10,
    'Trial11': df_trial11
}

# Convert each DataFrame row into OrderedDict and store
for sheet_name, df in trial_dfs.items():
    if df is not None:
        records = [OrderedDict(row.items()) for _, row in df.iterrows()]
        #print (records)
        ordered_data_by_sheet[sheet_name] = records


# Optional: print a preview
for sheet, records in ordered_data_by_sheet.items():
    print(f"\nSheet: {sheet}")
    for i, row in enumerate(records[:2]):  # preview first 2 rows per sheet
        print(f" Row {i+1}: {row}")
# Out:
# Sheets found: ['Trial1', 'Trial2', 'Trial3', 'Trial4', 'Trial5', 'Trial6', 'Trial7', 'Trial8', 'Trial9', 'Trial10', 'Trial11']
#
# Sheet: Trial1
#  Row 1: OrderedDict({'PlotID': 1, 'Replication': 'R1', 'Treatment': 'T1', 'Name of plot': 'R1T1', 'Date': '28/08/2023', 'Plant height': 51.16, 'Leaf length': 45.55, 'Psudostem Length': 6.0, 'Number of leaves': 6.5, 'Psuetostem width': 5.3, 'Leaf width': 3.31, 'PDI Stemphylium Blight': 0, 'PDI Purple blotch': 0, 'PDI AN': 0, 'Thrips': 43.3, 'new_thrips': 43.3, 'DAT': 48})
#  Row 2: OrderedDict({'PlotID': 2, 'Replication': 'R1', 'Treatment': 'T2', 'Name of plot': 'R1T2', 'Date': '28/08/2023', 'Plant height': 51.11, 'Leaf length': 43.01, 'Psudostem Length': 6.62, 'Number of leaves': 6.6, 'Psuetostem width': 11.02, 'Leaf width': 6.36, 'PDI Stemphylium Blight': 2, 'PDI Purple blotch': 0, 'PDI AN': 0, 'Thrips': 4.6, 'new_thrips': 4.6, 'DAT': 48})
#
# Sheet: Trial2
#  Row 1: OrderedDict({'PlotID': 1, 'Replication': 'R1', 'Treatment': 'T1', 'Name of plot': 'R1T1', 'Date': '28/08/2023', 'Plant height': 38.79, 'Leaf length': 34.25, 'Psudostem Length': 4.41, 'Number of leaves': 6.4, 'Psuetostem width': 8.72, 'Leaf width': 5.05, 'PDI Stemphylium Blight': 0, 'PDI Purple blotch': 0, 'PDI AN': 0, 'Thrips': 21.0, 'new_thrips': 21.0, 'DAT': 35})
#  Row 2: OrderedDict({'PlotID': 2, 'Replication': 'R1', 'Treatment': 'T2', 'Name of plot': 'R1T2', 'Date': '28/08/2023', 'Plant height': 42.71, 'Leaf length': 39.15, 'Psudostem Length': 4.18, 'Number of leaves': 6.3, 'Psuetostem width': 8.51, 'Leaf width': 5.24, 'PDI Stemphylium Blight': 0, 'PDI Purple blotch': 0, 'PDI AN': 0, 'Thrips': 4.6, 'new_thrips': 4.6, 'DAT': 35})
#
# Sheet: Trial3
#  Row 1: OrderedDict({'PlotID': 1, 'Replication': 'R1', 'Treatment': 'T1', 'Name of plot': 'R1T1', 'Date': '28/08/2023', 'Plant height': 22.32, 'Leaf length': 18.83, 'Psudostem Length': 2.91, 'Number of leaves': 4.1, 'Psuetostem width': 4.35, 'Leaf width': 3.19, 'PDI Stemphylium Blight': 0, 'PDI Purple blotch': 0, 'PDI AN': 0, 'Thrips': 6.7, 'new_thrips': 4.9, 'DAT': 20})
#  Row 2: OrderedDict({'PlotID': 2, 'Replication': 'R1', 'Treatment': 'T2', 'Name of plot': 'R1T2', 'Date': '28/08/2023', 'Plant height': 25.91, 'Leaf length': 22.33, 'Psudostem Length': 3.14, 'Number of leaves': 4.7, 'Psuetostem width': 5.04, 'Leaf width': 3.47, 'PDI Stemphylium Blight': 0, 'PDI Purple blotch': 0, 'PDI AN': 0, 'Thrips': 8.0, 'new_thrips': 6.7, 'DAT': 20})
#
# Sheet: Trial4
#  Row 1: OrderedDict({'PlotID': 1, 'Replication': 'R1', 'Treatment': 'T1', 'Name of plot': 'R1T1', 'Date': '14/09/2023', 'Plant height (cm)': 18.63, 'Leaf length(cm)': 16.1, 'Psudostem Length(cm)': 2.39, 'Number of leaves': 4.4, 'Psuetostem width(cm)': 4.15, 'Leaf width(cm)': 3.33, 'PDI Stemphylium Blight': 0, 'PDI Purple blotch': 0, 'PDI AN': 0, 'Unnamed: 14': nan, 'new_thrips': 17.4, 'DAT': 20})
#  Row 2: OrderedDict({'PlotID': 2, 'Replication': 'R1', 'Treatment': 'T2', 'Name of plot': 'R1T2', 'Date': '14/09/2023', 'Plant height (cm)': 20.04, 'Leaf length(cm)': 17.59, 'Psudostem Length(cm)': 2.44, 'Number of leaves': 4.2, 'Psuetostem width(cm)': 3.84, 'Leaf width(cm)': 3.06, 'PDI Stemphylium Blight': 0, 'PDI Purple blotch': 0, 'PDI AN': 0, 'Unnamed: 14': nan, 'new_thrips': 13.5, 'DAT': 20})
#
# Sheet: Trial5
#  Row 1: OrderedDict({'PlotID': 1, 'Replication': 'R1', 'Treatment': 'T1', 'Name of plot': 'R1T1', 'Date': '20/10/2023', 'Plant height (cm)': 30.76, 'Leaf length(cm)': 27.3, 'Psudostem Length(cm)': 3.13, 'Number of leaves': 4.6, 'Psuetostem width(cm)': 6.48, 'Leaf width(cm)': 4.83, 'PDI Stemphylium Blight': 4, 'PDI Purple blotch': 2, 'PDI AN': 6, 'new_thrips': nan})
#  Row 2: OrderedDict({'PlotID': 2, 'Replication': 'R1', 'Treatment': 'T2', 'Name of plot': 'R1T2', 'Date': '20/10/2023', 'Plant height (cm)': 34.46, 'Leaf length(cm)': 30.9, 'Psudostem Length(cm)': 3.53, 'Number of leaves': 5.5, 'Psuetostem width(cm)': 7.24, 'Leaf width(cm)': 5.34, 'PDI Stemphylium Blight': 4, 'PDI Purple blotch': 4, 'PDI AN': 4, 'new_thrips': nan})
#
# Sheet: Trial6
#  Row 1: OrderedDict({'PlotID': 1, 'Replication': 'R1', 'Treatment': 'T1', 'Name of plot': 'R1T1', 'Date': '20/10/2023', 'Plant height (cm)': 14.652, 'Leaf length(cm)': 11.23, 'Psudostem Length(cm)': 3.17, 'Number of leaves': 2.4, 'Psuetostem width(cm)': 4.002, 'Leaf width(cm)': 3.72, 'PDI Stemphylium Blight': nan, 'PDI Purple blotch': nan, 'PDI AN': nan})
#  Row 2: OrderedDict({'PlotID': 2, 'Replication': 'R1', 'Treatment': 'T2', 'Name of plot': 'R1T2', 'Date': '20/10/2023', 'Plant height (cm)': 14.94, 'Leaf length(cm)': 11.84, 'Psudostem Length(cm)': 3.24, 'Number of leaves': 3.0, 'Psuetostem width(cm)': 3.553, 'Leaf width(cm)': 3.009, 'PDI Stemphylium Blight': nan, 'PDI Purple blotch': nan, 'PDI AN': nan})
#
# Sheet: Trial7
#  Row 1: OrderedDict({'PlotID': 1, 'Replication': 'R1', 'Treatment': 'T1', 'Name of plot': 'R1T1', 'Date': '30/10/2023', 'Plant height (cm)': 14.58, 'Leaf length(cm)': 12.19, 'Psudostem Length(cm)': 2.3, 'Number of leaves': 2.9, 'Psuetostem width(cm)': 3.45499999999999, 'Leaf width(cm)': 3.022})
#  Row 2: OrderedDict({'PlotID': 2, 'Replication': 'R1', 'Treatment': 'T2', 'Name of plot': 'R1T2', 'Date': '30/10/2023', 'Plant height (cm)': 14.83, 'Leaf length(cm)': 12.39, 'Psudostem Length(cm)': 2.27, 'Number of leaves': 3.5, 'Psuetostem width(cm)': 3.664, 'Leaf width(cm)': 3.513})
#
# Sheet: Trial8
#  Row 1: OrderedDict({'PlotID': 1, 'Replication': 'R1', 'Treatment': 'T1', 'Name of plot': 'R1T1', 'Date': '25/11/2023', 'Plant height (cm)': 21.05, 'Leaf length(cm)': 16.71, 'Psudostem Length(cm)': 3.67999999999999, 'Number of leaves': 2.6, 'Psuetostem width(cm)': 3.304, 'Leaf width(cm)': 2.932})
#  Row 2: OrderedDict({'PlotID': 2, 'Replication': 'R1', 'Treatment': 'T2', 'Name of plot': 'R1T2', 'Date': '25/11/2023', 'Plant height (cm)': 21.79, 'Leaf length(cm)': 17.5099999999999, 'Psudostem Length(cm)': 3.87, 'Number of leaves': 2.6, 'Psuetostem width(cm)': 3.054, 'Leaf width(cm)': 2.689})
#
# Sheet: Trial9
#  Row 1: OrderedDict({'PlotID': 1, 'Replication': 'R1', 'Treatment': 'T1', 'Name of plot': 'R1T1', 'Date': '30/12/2023', 'Plant height (cm)': 28.4, 'Leaf length(cm)': 23.2, 'Psudostem Length(cm)': 4.5, 'Number of leaves': 4.0, 'Psuetostem width(cm)': 6.61, 'Leaf width(cm)': 6.87})
#  Row 2: OrderedDict({'PlotID': 2, 'Replication': 'R1', 'Treatment': 'T2', 'Name of plot': 'R1T2', 'Date': '30/12/2023', 'Plant height (cm)': 27.0, 'Leaf length(cm)': 23.9, 'Psudostem Length(cm)': 3.0, 'Number of leaves': 5.0, 'Psuetostem width(cm)': 4.85, 'Leaf width(cm)': 5.14})
#
# Sheet: Trial10
#  Row 1: OrderedDict({'PlotID': 1, 'Replication': 'R1', 'Treatment': 'T1', 'Name of plot': 'R1T1', 'Date': '19/01/2024', 'Plant height (cm)': 18.5, 'Leaf length(cm)': 16.1, 'Psudostem Length(cm)': 3.0, 'Number of leaves': 3.0, 'Psuetostem width(cm)': 3.52, 'Leaf width(cm)': 3.24})
#  Row 2: OrderedDict({'PlotID': 2, 'Replication': 'R1', 'Treatment': 'T2', 'Name of plot': 'R1T2', 'Date': '19/01/2024', 'Plant height (cm)': 18.4, 'Leaf length(cm)': 15.6, 'Psudostem Length(cm)': 2.6, 'Number of leaves': 3.0, 'Psuetostem width(cm)': 3.69, 'Leaf width(cm)': 4.23})
#
# Sheet: Trial11
#  Row 1: OrderedDict({'PlotID': 1, 'Replication': 'R1', 'Treatment': 'T1', 'Name of plot': 'R1T1', 'Date': '09/02/2024', 'Plant height (cm)': 22.1, 'Leaf length(cm)': 19.4, 'Psudostem Length(cm)': 3.0, 'Number of leaves': 4, 'Psuetostem width(cm)': 4.89, 'Leaf width(cm)': 3.92})
#  Row 2: OrderedDict({'PlotID': 2, 'Replication': 'R1', 'Treatment': 'T2', 'Name of plot': 'R1T2', 'Date': '09/02/2024', 'Plant height (cm)': 21.1, 'Leaf length(cm)': 17.3, 'Psudostem Length(cm)': 3.5, 'Number of leaves': 4, 'Psuetostem width(cm)': 4.35, 'Leaf width(cm)': 3.96})

# %%
from copy import deepcopy
from datetime import datetime

updated_unique_dates = OrderedDict()
for trial_key in ordered_data_by_sheet:
    trial_data = ordered_data_by_sheet[trial_key]
    # Prepare to hold enriched rows
    if trial_key not in updated_unique_dates:
        #updated_unique_dates[trial_key] = []
        dates_in_trials = []
        for main_row in trial_data:
            dates_in_trials.append(main_row.get('Date'))
        # Convert to datetime, remove duplicates, sort, then format back to string
        # Convert to datetime, remove duplicates, sort, then format back to string
        unique_sorted_dates = sorted(set(datetime.strptime(date, "%d/%m/%Y") for date in dates_in_trials))
        unique_dates = [date.strftime("%d/%m/%Y") for date in unique_sorted_dates]
        
        #print(unique_dates)
        updated_unique_dates[trial_key] = unique_dates

print (updated_unique_dates)
# Out:
# OrderedDict({'Trial1': ['28/08/2023', '07/09/2023', '14/09/2023', '25/09/2023'], 'Trial2': ['28/08/2023', '07/09/2023', '14/09/2023', '25/09/2023'], 'Trial3': ['28/08/2023', '07/09/2023', '14/09/2023', '25/09/2023', '20/10/2023', '30/10/2023'], 'Trial4': ['10/09/2023', '14/09/2023', '25/09/2023', '20/10/2023', '30/10/2023'], 'Trial5': ['20/10/2023', '30/10/2023', '10/11/2023', '16/11/2023', '25/11/2023'], 'Trial6': ['20/10/2023', '30/10/2023', '10/11/2023', '16/11/2023', '25/11/2023', '01/12/2023', '14/12/2023', '20/12/2023', '30/12/2023', '04/01/2024'], 'Trial7': ['30/10/2023', '10/11/2023', '16/11/2023', '25/11/2023', '01/12/2023', '14/12/2023', '20/12/2023', '30/12/2023', '04/01/2024', '19/01/2024'], 'Trial8': ['25/11/2023', '01/12/2023', '14/12/2023', '20/12/2023', '30/12/2023', '04/01/2024', '19/01/2024', '09/02/2024', '16/02/2024'], 'Trial9': ['30/12/2023', '04/01/2024', '19/01/2024', '09/02/2024', '16/02/2024', '01/03/2024', '07/03/2024', '15/03/2024'], 'Trial10': ['19/01/2024', '09/02/2024', '16/02/2024', '01/03/2024', '07/03/2024', '15/03/2024', '22/03/2024', '28/03/2024'], 'Trial11': ['09/02/2024', '16/02/2024', '01/03/2024', '07/03/2024', '15/03/2024', '22/03/2024', '28/03/2024']})

# %%
from collections import OrderedDict
from datetime import datetime, timedelta

dates_past7 = OrderedDict()

for trial_key in updated_unique_dates:
    dates_past7[trial_key] = {}
    for date_in_trial in updated_unique_dates[trial_key]:
        # Convert string to datetime
        date_obj = datetime.strptime(date_in_trial, "%d/%m/%Y")
        
        # Get past 7 days *excluding* the current date
        past_7_days = [(date_obj - timedelta(days=i)).strftime("%d/%m/%Y") for i in reversed(range(1, 8))]
        
        # Store the result
        dates_past7[trial_key][date_in_trial] = past_7_days

print (dates_past7['Trial11']['22/03/2024'])
# Out:
# ['15/03/2024', '16/03/2024', '17/03/2024', '18/03/2024', '19/03/2024', '20/03/2024', '21/03/2024']

# %%
import csv
from collections import OrderedDict
from datetime import datetime
import pandas as pd

# Initialize ordered_dict_weather as an empty list
ordered_dict_weather = []

# Load the CSV data and create the ordered_dict_weather list (Code 1)
with open('weather.csv', mode='r', newline='') as file:
    reader = csv.DictReader(file)
    for row in reader:
        ordered_row = OrderedDict()
        for key, value in row.items():
            if key == 'Date(IST)':  # Modify this if your column name differs
                # Try to standardize the date format if necessary
                value = value.strip()
                # Replace '/' or '.' with '-' to handle common formats
                value = value.replace('/', '-').replace('.', '-')
                # Now parse it
                try:
                    dt = datetime.strptime(value, "%d-%m-%Y %H:%M")
                except ValueError:
                    try:
                        dt = datetime.strptime(value, "%d-%m-%Y")
                    except ValueError:
                        dt = None  # Or handle it as needed
                value = dt
            ordered_row[key] = value
        ordered_dict_weather.append(ordered_row)

# Sort by the parsed datetime object
DATE_COLUMN = 'Date(IST)'  # Change if needed
ordered_dict_weather = [row for row in ordered_dict_weather if row[DATE_COLUMN] is not None]
ordered_dict_weather.sort(key=lambda x: x[DATE_COLUMN])

# Load the Excel data and create the records_filtered list (Code 2)
# Load all sheets from the Excel file
xls = pd.read_excel('Jan-Sept_2024_Weather_data.xlsx', sheet_name=None)

# Get specific sheet (datewise-data)
df_weather24 = xls.get('datewise-data')

# Convert 'Date & Time' to datetime format
df_weather24['Date & Time'] = pd.to_datetime(df_weather24['Date & Time'], errors='coerce')

# Filter data between January and April
df_filtered = df_weather24[(df_weather24['Date & Time'].dt.month >= 1) & (df_weather24['Date & Time'].dt.month <= 4)]

# Select the relevant columns
columns_to_keep = ['Date & Time', 'Air Temperature (Deg C)', 'Air RH (%)', 'Rainfall (mm)']
df_filtered = df_filtered[columns_to_keep]

# Create an OrderedDict with the new keys
records_filtered = []
for _, row in df_filtered.iterrows():
    # Format the Date & Time to 'DD-MM-YYYY HH:MM' (IST)
    formatted_date = row['Date & Time'].strftime('%d-%m-%Y %H:%M')
    
    # Create OrderedDict with new keys and formatted values
    row_dict = OrderedDict({
        'Date(IST)': formatted_date,
        'Temp': f"{row['Air Temperature (Deg C)']:.2f}",
        'RH(%)': f"{row['Air RH (%)']:.2f}",
        'Rain(mm)': f"{row['Rainfall (mm)']:.2f}"
    })
    records_filtered.append(row_dict)

# Append records_filtered to ordered_dict_weather
ordered_dict_weather += records_filtered  # Or you can use ordered_dict_weather.extend(records_filtered)

# Print the total number of rows in the combined list
print(f"Total rows after appending: {len(ordered_dict_weather)}")

# Optional: Convert datetime back to string if printing
for item in ordered_dict_weather[:10]:  # Print the first 10 records
    dt_obj = item[DATE_COLUMN]
    item[DATE_COLUMN] = dt_obj.strftime("%d-%m-%Y %H:%M") if isinstance(dt_obj, datetime) else dt_obj
    print(item)
# Out:
# Total rows after appending: 43832
# OrderedDict({'Date(IST)': '01-01-2023 00:00', 'Temp': '17.05', 'RH(%)': '74.05', 'Rain(mm)': '0'})
# OrderedDict({'Date(IST)': '01-01-2023 00:15', 'Temp': '16.78', 'RH(%)': '75.18', 'Rain(mm)': '0'})
# OrderedDict({'Date(IST)': '01-01-2023 00:30', 'Temp': '16.65', 'RH(%)': '76.67', 'Rain(mm)': '0'})
# OrderedDict({'Date(IST)': '01-01-2023 00:45', 'Temp': '16.55', 'RH(%)': '76.35', 'Rain(mm)': '0'})
# OrderedDict({'Date(IST)': '01-01-2023 01:00', 'Temp': '14.63', 'RH(%)': '85.05', 'Rain(mm)': '0'})
# OrderedDict({'Date(IST)': '01-01-2023 01:15', 'Temp': '14.32', 'RH(%)': '86.95', 'Rain(mm)': '0'})
# OrderedDict({'Date(IST)': '01-01-2023 01:30', 'Temp': '14.2', 'RH(%)': '88.05', 'Rain(mm)': '0'})
# OrderedDict({'Date(IST)': '01-01-2023 01:45', 'Temp': '14.17', 'RH(%)': '88.4', 'Rain(mm)': '0'})
# OrderedDict({'Date(IST)': '01-01-2023 02:00', 'Temp': '13.68', 'RH(%)': '89.9', 'Rain(mm)': '0'})
# OrderedDict({'Date(IST)': '01-01-2023 02:15', 'Temp': '13.53', 'RH(%)': '89.68', 'Rain(mm)': '0'})

# %%
from collections import OrderedDict, defaultdict
from datetime import datetime


def parse_datetime_safe(date_str):
    for fmt in ("%Y-%m-%d %H:%M:%S", "%d-%m-%Y %H:%M"):
        try:
            return datetime.strptime(date_str, fmt)
        except ValueError:
            continue
    raise ValueError(f"Date format not recognized: {date_str}")

# Apply parsing
for entry in ordered_dict_weather:
    date_str = str(entry['Date(IST)'])  # make sure it's a string
    date_obj = parse_datetime_safe(date_str)
    entry['date_only'] = date_obj.date()

'''
# Initialize result container
filtered_weather_by_trial = defaultdict(lambda: defaultdict(list))

# Loop through each trial and its dates
for trial_name, date_list in updated_unique_dates.items():
    for date_str in date_list:
        target_date = datetime.strptime(date_str, "%d/%m/%Y").date()
        for entry in ordered_dict_weather:
            if entry['date_only'] == target_date:
                filtered_weather_by_trial[trial_name][date_str].append(entry)

# Remove helper field before final output (optional)
for trial in filtered_weather_by_trial:
    for date in filtered_weather_by_trial[trial]:
        for entry in filtered_weather_by_trial[trial][date]:
            entry.pop('date_only', None)

# Display result
from pprint import pprint
pprint(dict(filtered_weather_by_trial['Trial7']))
'''
# Out:
# '\n# Initialize result container\nfiltered_weather_by_trial = defaultdict(lambda: defaultdict(list))\n\n# Loop through each trial and its dates\nfor trial_name, date_list in updated_unique_dates.items():\n    for date_str in date_list:\n        target_date = datetime.strptime(date_str, "%d/%m/%Y").date()\n        for entry in ordered_dict_weather:\n            if entry[\'date_only\'] == target_date:\n                filtered_weather_by_trial[trial_name][date_str].append(entry)\n\n# Remove helper field before final output (optional)\nfor trial in filtered_weather_by_trial:\n    for date in filtered_weather_by_trial[trial]:\n        for entry in filtered_weather_by_trial[trial][date]:\n            entry.pop(\'date_only\', None)\n\n# Display result\nfrom pprint import pprint\npprint(dict(filtered_weather_by_trial[\'Trial7\']))\n'

# %%
from collections import OrderedDict
from datetime import datetime, time

# Helper: handle multiple datetime formats
def parse_datetime_safe(date_str):
    for fmt in ("%Y-%m-%d %H:%M:%S", "%d-%m-%Y %H:%M"):
        try:
            return datetime.strptime(date_str, fmt)
        except ValueError:
            continue
    raise ValueError(f"Date format not recognized: {date_str}")

# Define time slots
time_slots = OrderedDict({
    '4-8am':   (time(4, 0), time(8, 0)),
    '8-10am':  (time(8, 0), time(10, 0)),
    '10-12pm': (time(10, 0), time(12, 0)),
    '12-2pm':  (time(12, 0), time(14, 0)),
    '2-4pm':   (time(14, 0), time(16, 0))
})

# Step 1: Add 'date_only' and 'time_only' to each weather entry
for entry in ordered_dict_weather:
    dt = parse_datetime_safe(str(entry['Date(IST)']))
    entry['date_only'] = dt.date()
    entry['time_only'] = dt.time()

# Step 2: Create the nested OrderedDict
filtered_weather_by_trial = OrderedDict()

# Step 3: Populate with time-slot-grouped entries
for trial_name, date_list in updated_unique_dates.items():
    filtered_weather_by_trial[trial_name] = OrderedDict()
    for date_str in date_list:
        target_date = datetime.strptime(date_str, "%d/%m/%Y").date()
        # Initialize slot container
        slot_entries = OrderedDict((slot_name, []) for slot_name in time_slots)

        # Filter and assign to slot
        for entry in ordered_dict_weather:
            if entry['date_only'] == target_date:
                entry_time = entry['time_only']
                for slot_name, (start, end) in time_slots.items():
                    if start <= entry_time < end:
                        cleaned_entry = entry.copy()
                        cleaned_entry.pop('date_only', None)
                        cleaned_entry.pop('time_only', None)
                        slot_entries[slot_name].append(cleaned_entry)
                        break

        filtered_weather_by_trial[trial_name][date_str] = slot_entries

# Print result
from pprint import pprint
pprint(filtered_weather_by_trial['Trial11']['28/03/2024'])
# Out:
# OrderedDict([('4-8am',
#               [OrderedDict([('Date(IST)', '28-03-2024 04:03'),
#                             ('Temp', '20.70'),
#                             ('RH(%)', '75.00'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 04:18'),
#                             ('Temp', '20.80'),
#                             ('RH(%)', '75.80'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 04:33'),
#                             ('Temp', '20.60'),
#                             ('RH(%)', '76.30'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 04:48'),
#                             ('Temp', '20.50'),
#                             ('RH(%)', '74.80'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 05:03'),
#                             ('Temp', '20.20'),
#                             ('RH(%)', '76.40'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 05:18'),
#                             ('Temp', '20.20'),
#                             ('RH(%)', '77.60'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 05:33'),
#                             ('Temp', '20.10'),
#                             ('RH(%)', '77.60'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 05:48'),
#                             ('Temp', '20.10'),
#                             ('RH(%)', '77.20'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 06:03'),
#                             ('Temp', '19.70'),
#                             ('RH(%)', '78.10'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 06:18'),
#                             ('Temp', '19.70'),
#                             ('RH(%)', '75.00'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 06:33'),
#                             ('Temp', '19.70'),
#                             ('RH(%)', '78.50'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 06:48'),
#                             ('Temp', '19.60'),
#                             ('RH(%)', '79.60'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 07:03'),
#                             ('Temp', '19.70'),
#                             ('RH(%)', '79.70'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 07:18'),
#                             ('Temp', '20.30'),
#                             ('RH(%)', '77.70'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 07:33'),
#                             ('Temp', '20.40'),
#                             ('RH(%)', '77.40'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 07:48'),
#                             ('Temp', '21.10'),
#                             ('RH(%)', '75.50'),
#                             ('Rain(mm)', '0.00')])]),
#              ('8-10am',
#               [OrderedDict([('Date(IST)', '28-03-2024 08:03'),
#                             ('Temp', '22.10'),
#                             ('RH(%)', '75.50'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 08:18'),
#                             ('Temp', '23.00'),
#                             ('RH(%)', '70.60'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 08:33'),
#                             ('Temp', '24.30'),
#                             ('RH(%)', '66.10'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 08:48'),
#                             ('Temp', '25.40'),
#                             ('RH(%)', '62.40'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 09:03'),
#                             ('Temp', '26.80'),
#                             ('RH(%)', '59.20'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 09:18'),
#                             ('Temp', '28.80'),
#                             ('RH(%)', '52.20'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 09:33'),
#                             ('Temp', '29.70'),
#                             ('RH(%)', '41.10'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 09:48'),
#                             ('Temp', '31.00'),
#                             ('RH(%)', '38.70'),
#                             ('Rain(mm)', '0.00')])]),
#              ('10-12pm',
#               [OrderedDict([('Date(IST)', '28-03-2024 10:03'),
#                             ('Temp', '31.50'),
#                             ('RH(%)', '36.80'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 10:18'),
#                             ('Temp', '32.50'),
#                             ('RH(%)', '31.30'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 10:33'),
#                             ('Temp', '33.50'),
#                             ('RH(%)', '28.70'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 10:48'),
#                             ('Temp', '33.60'),
#                             ('RH(%)', '27.70'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 11:03'),
#                             ('Temp', '34.70'),
#                             ('RH(%)', '26.40'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 11:18'),
#                             ('Temp', '34.50'),
#                             ('RH(%)', '26.50'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 11:33'),
#                             ('Temp', '35.40'),
#                             ('RH(%)', '25.60'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 11:48'),
#                             ('Temp', '35.60'),
#                             ('RH(%)', '27.90'),
#                             ('Rain(mm)', '0.00')])]),
#              ('12-2pm',
#               [OrderedDict([('Date(IST)', '28-03-2024 12:03'),
#                             ('Temp', '35.80'),
#                             ('RH(%)', '26.80'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 12:18'),
#                             ('Temp', '36.50'),
#                             ('RH(%)', '25.80'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 12:33'),
#                             ('Temp', '36.90'),
#                             ('RH(%)', '27.20'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 12:48'),
#                             ('Temp', '36.90'),
#                             ('RH(%)', '27.80'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 13:03'),
#                             ('Temp', '36.40'),
#                             ('RH(%)', '26.60'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 13:18'),
#                             ('Temp', '37.50'),
#                             ('RH(%)', '26.30'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 13:33'),
#                             ('Temp', '37.70'),
#                             ('RH(%)', '26.00'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 13:48'),
#                             ('Temp', '37.70'),
#                             ('RH(%)', '25.60'),
#                             ('Rain(mm)', '0.00')])]),
#              ('2-4pm',
#               [OrderedDict([('Date(IST)', '28-03-2024 14:03'),
#                             ('Temp', '38.00'),
#                             ('RH(%)', '25.40'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 14:18'),
#                             ('Temp', '37.50'),
#                             ('RH(%)', '26.20'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 14:33'),
#                             ('Temp', '38.50'),
#                             ('RH(%)', '25.60'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 14:48'),
#                             ('Temp', '37.70'),
#                             ('RH(%)', '25.10'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 15:03'),
#                             ('Temp', '38.30'),
#                             ('RH(%)', '24.20'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 15:18'),
#                             ('Temp', '38.50'),
#                             ('RH(%)', '28.60'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 15:33'),
#                             ('Temp', '38.40'),
#                             ('RH(%)', '23.50'),
#                             ('Rain(mm)', '0.00')]),
#                OrderedDict([('Date(IST)', '28-03-2024 15:48'),
#                             ('Temp', '38.60'),
#                             ('RH(%)', '22.60'),
#                             ('Rain(mm)', '0.00')])])])

# %%
from collections import OrderedDict
from datetime import datetime, time

# Helper: handle multiple datetime formats
def parse_datetime_safe(date_str):
    for fmt in ("%Y-%m-%d %H:%M:%S", "%d-%m-%Y %H:%M"):
        try:
            return datetime.strptime(date_str, fmt)
        except ValueError:
            continue
    raise ValueError(f"Date format not recognized: {date_str}")

# Define time slots
time_slots = OrderedDict({
    '4-8am':   (time(4, 0), time(8, 0)),
    '8-10am':  (time(8, 0), time(10, 0)),
    '10-12pm': (time(10, 0), time(12, 0)),
    '12-2pm':  (time(12, 0), time(14, 0)),
    '2-4pm':   (time(14, 0), time(16, 0))
})

# Step 1: Pre-process weather entries with parsed date and time
for entry in ordered_dict_weather:
    dt = parse_datetime_safe(str(entry['Date(IST)']))
    entry['date_only'] = dt.date()
    entry['time_only'] = dt.time()

# Step 2: Create the filtered_by_past7days dictionary
filtered_by_past7days = OrderedDict()

for trial_name, date_dict in dates_past7.items():
    filtered_by_past7days[trial_name] = OrderedDict()

    for current_date_str, past_7_dates in date_dict.items():
        # Initialize slot containers for the current_date
        slot_entries = OrderedDict((slot_name, []) for slot_name in time_slots)

        # Convert date strings to date objects for comparison
        past_dates = [datetime.strptime(d, "%d/%m/%Y").date() for d in past_7_dates]

        # Filter and group all relevant weather entries
        for entry in ordered_dict_weather:
            if entry['date_only'] in past_dates:
                entry_time = entry['time_only']
                for slot_name, (start, end) in time_slots.items():
                    if start <= entry_time < end:
                        cleaned_entry = entry.copy()
                        cleaned_entry.pop('date_only', None)
                        cleaned_entry.pop('time_only', None)
                        slot_entries[slot_name].append(cleaned_entry)
                        break

        # Store accumulated slot-wise entries under current_date_str
        filtered_by_past7days[trial_name][current_date_str] = slot_entries
print (filtered_by_past7days['Trial11']['28/03/2024']['10-12pm'])
# Out:
# [OrderedDict({'Date(IST)': '21-03-2024 10:03', 'Temp': '29.30', 'RH(%)': '34.80', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '21-03-2024 10:18', 'Temp': '29.20', 'RH(%)': '35.60', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '21-03-2024 10:33', 'Temp': '30.30', 'RH(%)': '35.80', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '21-03-2024 10:48', 'Temp': '30.70', 'RH(%)': '37.40', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '21-03-2024 11:03', 'Temp': '30.90', 'RH(%)': '37.00', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '21-03-2024 11:18', 'Temp': '31.40', 'RH(%)': '36.40', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '21-03-2024 11:33', 'Temp': '31.50', 'RH(%)': '35.90', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '21-03-2024 11:48', 'Temp': '32.60', 'RH(%)': '34.60', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '22-03-2024 10:03', 'Temp': '30.90', 'RH(%)': '32.60', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '22-03-2024 10:18', 'Temp': '31.90', 'RH(%)': '28.00', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '22-03-2024 10:33', 'Temp': '32.00', 'RH(%)': '28.10', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '22-03-2024 10:48', 'Temp': '32.30', 'RH(%)': '27.40', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '22-03-2024 11:03', 'Temp': '33.30', 'RH(%)': '27.80', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '22-03-2024 11:18', 'Temp': '33.70', 'RH(%)': '23.70', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '22-03-2024 11:33', 'Temp': '33.60', 'RH(%)': '26.10', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '22-03-2024 11:48', 'Temp': '34.40', 'RH(%)': '24.80', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '23-03-2024 10:03', 'Temp': '30.60', 'RH(%)': '36.90', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '23-03-2024 10:18', 'Temp': '31.40', 'RH(%)': '37.90', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '23-03-2024 10:33', 'Temp': '32.50', 'RH(%)': '32.60', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '23-03-2024 10:48', 'Temp': '32.60', 'RH(%)': '26.60', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '23-03-2024 11:03', 'Temp': '33.40', 'RH(%)': '29.60', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '23-03-2024 11:18', 'Temp': '33.40', 'RH(%)': '22.20', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '23-03-2024 11:33', 'Temp': '33.60', 'RH(%)': '23.10', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '23-03-2024 11:48', 'Temp': '33.70', 'RH(%)': '24.00', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '24-03-2024 10:03', 'Temp': '30.00', 'RH(%)': '30.50', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '24-03-2024 10:18', 'Temp': '30.80', 'RH(%)': '31.40', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '24-03-2024 10:33', 'Temp': '31.90', 'RH(%)': '28.70', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '24-03-2024 10:48', 'Temp': '32.50', 'RH(%)': '26.20', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '24-03-2024 11:03', 'Temp': '32.60', 'RH(%)': '25.70', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '24-03-2024 11:18', 'Temp': '34.00', 'RH(%)': '29.60', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '24-03-2024 11:33', 'Temp': '34.00', 'RH(%)': '23.10', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '24-03-2024 11:48', 'Temp': '33.70', 'RH(%)': '23.70', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '25-03-2024 10:03', 'Temp': '30.90', 'RH(%)': '45.20', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '25-03-2024 10:18', 'Temp': '32.00', 'RH(%)': '40.60', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '25-03-2024 10:33', 'Temp': '32.60', 'RH(%)': '32.80', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '25-03-2024 10:48', 'Temp': '33.30', 'RH(%)': '28.00', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '25-03-2024 11:03', 'Temp': '33.90', 'RH(%)': '25.90', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '25-03-2024 11:18', 'Temp': '34.70', 'RH(%)': '25.10', 'Rain(mm)': '0.00'}), OrderedDict({'Date(IST)': '25-03-2024 11:33', 'Temp': '35.00', 'RH(%)': '27.60', 'Rai ...

# %%
from collections import OrderedDict
import numpy as np

weather_master = OrderedDict()
temp_last_7 = []
RH_last_7 = []
Rain_last_7 = []
for trial_key in filtered_by_past7days:
    if trial_key not in weather_master:
        weather_master[trial_key] = OrderedDict()
        
        for date_curr in filtered_by_past7days[trial_key]:
            if date_curr not in weather_master[trial_key]:
                weather_master[trial_key][date_curr] = OrderedDict()
                
            for time_block in filtered_by_past7days[trial_key][date_curr]:
                if time_block not in weather_master[trial_key][date_curr]:
                    weather_master[trial_key][date_curr][time_block] = {}
                    
                for data in filtered_by_past7days[trial_key][date_curr][time_block]:
                    temp_last_7.append(float(data['Temp']))
                    RH_last_7.append(float(data['RH(%)']))
                    Rain_last_7.append(float(data['Rain(mm)']))
                #print (trial_key, date_curr, time_block, temp_last_7, max(temp_last_7), np.mean(temp_last_7))
                weather_master[trial_key][date_curr][time_block]['Tmax-7'] = max(temp_last_7)  
                weather_master[trial_key][date_curr][time_block]['Tmin-7'] = min(temp_last_7)    
                weather_master[trial_key][date_curr][time_block]['Tavg-7'] = np.mean(temp_last_7)    
                weather_master[trial_key][date_curr][time_block]['RHmax-7'] = max(RH_last_7)  
                weather_master[trial_key][date_curr][time_block]['RHmin-7'] = min(RH_last_7)    
                weather_master[trial_key][date_curr][time_block]['RHavg-7'] = np.mean(RH_last_7)
                weather_master[trial_key][date_curr][time_block]['Rainmax-7'] = max(Rain_last_7)  
                weather_master[trial_key][date_curr][time_block]['Rainmin-7'] = min(Rain_last_7)    
                weather_master[trial_key][date_curr][time_block]['Rainavg-7'] = np.mean(Rain_last_7)
            #break
#print (weather_master['Trial11']['22/03/2024'])
print (weather_master['Trial1']['28/08/2023'])
print ("\n\n")
print (weather_master['Trial2']['28/08/2023'])
# Out:
# OrderedDict({'4-8am': {'Tmax-7': 24.7, 'Tmin-7': 21.7, 'Tavg-7': 22.978378378378373, 'RHmax-7': 94.0, 'RHmin-7': 88.0, 'RHavg-7': 91.54054054054055, 'Rainmax-7': 17.5, 'Rainmin-7': 0.0, 'Rainavg-7': 3.68018018018018}, '8-10am': {'Tmax-7': 27.2, 'Tmin-7': 21.7, 'Tavg-7': 23.84311377245509, 'RHmax-7': 94.0, 'RHmin-7': 78.0, 'RHavg-7': 89.73652694610779, 'Rainmax-7': 18.0, 'Rainmin-7': 0.0, 'Rainavg-7': 2.940119760479042}, '10-12pm': {'Tmax-7': 28.9, 'Tmin-7': 21.7, 'Tavg-7': 24.627802690582957, 'RHmax-7': 94.0, 'RHmin-7': 70.0, 'RHavg-7': 87.14798206278027, 'Rainmax-7': 18.0, 'Rainmin-7': 0.0, 'Rainavg-7': 2.2242152466367715}, '12-2pm': {'Tmax-7': 29.7, 'Tmin-7': 21.7, 'Tavg-7': 25.210394265232978, 'RHmax-7': 94.0, 'RHmin-7': 69.0, 'RHavg-7': 85.3763440860215, 'Rainmax-7': 18.0, 'Rainmin-7': 0.0, 'Rainavg-7': 1.8172043010752688}, '2-4pm': {'Tmax-7': 29.9, 'Tmin-7': 21.7, 'Tavg-7': 25.582985074626862, 'RHmax-7': 94.0, 'RHmin-7': 66.0, 'RHavg-7': 84.2358208955224, 'Rainmax-7': 18.0, 'Rainmin-7': 0.0, 'Rainavg-7': 1.6791044776119404}})
# OrderedDict({'4-8am': {'Tmax-7': 35.3, 'Tmin-7': 21.4, 'Tavg-7': 26.001409443269907, 'RHmax-7': 94.0, 'RHmin-7': 40.0, 'RHavg-7': 77.37420718816068, 'Rainmax-7': 25.5, 'Rainmin-7': 0.0, 'Rainavg-7': 2.13953488372093}, '8-10am': {'Tmax-7': 35.3, 'Tmin-7': 21.4, 'Tavg-7': 25.984542372881354, 'RHmax-7': 94.0, 'RHmin-7': 40.0, 'RHavg-7': 77.7077966101695, 'Rainmax-7': 25.5, 'Rainmin-7': 0.0, 'Rainavg-7': 2.1142372881355933}, '10-12pm': {'Tmax-7': 35.3, 'Tmin-7': 21.4, 'Tavg-7': 26.020509470934027, 'RHmax-7': 94.0, 'RHmin-7': 40.0, 'RHavg-7': 77.77073807968648, 'Rainmax-7': 25.5, 'Rainmin-7': 0.0, 'Rainavg-7': 2.0401698236446766}, '12-2pm': {'Tmax-7': 35.3, 'Tmin-7': 21.4, 'Tavg-7': 26.073787019533714, 'RHmax-7': 94.0, 'RHmin-7': 40.0, 'RHavg-7': 77.79017013232514, 'Rainmax-7': 25.5, 'Rainmin-7': 0.0, 'Rainavg-7': 1.9751102709514807}, '2-4pm': {'Tmax-7': 35.3, 'Tmin-7': 21.4, 'Tavg-7': 26.120328667072428, 'RHmax-7': 94.0, 'RHmin-7': 40.0, 'RHavg-7': 77.81618989653073, 'Rainmax-7': 25.5, 'Rainmin-7': 0.0, 'Rainavg-7': 1.941570298234936}})
