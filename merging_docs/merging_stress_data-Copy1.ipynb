# %%
import pandas as pd

# PDI data
df_pdi = pd.read_csv('pdi_data.csv')
#print (df_pdi.head())

# %%
unique_trials_dis = df_pdi['Trial name'].unique()
unique_trials_list_dis = unique_trials_dis.tolist()
print (unique_trials_list_dis)
# Out:
# ['Trial 5', 'Trial 6', 'Trial 7', 'Trial 8', 'Trial 9']

# %%
# Thrips data
df_th = pd.read_csv('thrips_data.csv')
#print (df_th.head())
#print(df_th.columns)

# %%
unique_trials_pt = df_th['Trial_name'].unique()
unique_trials_list_pt = unique_trials_pt.tolist()
print (unique_trials_list_pt)
# Out:
# ['Trial1', 'Trial 2', 'Trial 3', 'Trial 4', 'Trial 5', 'Trial 6', 'Trial 7', 'Trial 8', 'Trial 9', 'Trial 10', 'Trial 11', 'Trial 12']

# %%
import pandas as pd

# Read all sheets from the Excel file into a dictionary
xls = pd.read_excel('MASTER_DF_updated.xlsx', sheet_name=None)

# View all available sheet names
sheet_names = list(xls.keys())
print("Sheets found:", sheet_names)

# Access each sheet individually for separate use

df_trial1 = xls.get('Trial1')
df_trial2 = xls.get('Trial2')
df_trial3 = xls.get('Trial3')
df_trial4 = xls.get('Trial4')
df_trial5 = xls.get('Trial5')
df_trial6 = xls.get('Trial6')
df_trial7 = xls.get('Trial7')
df_trial8 = xls.get('Trial8')
df_trial9 = xls.get('Trial9')
df_trial10 = xls.get('Trial10')
df_trial11 = xls.get('Trial11')

# Example: print the first few rows of each trial
'''
print("=== Trial 1 ===")
print(df_trial1.head())

print("=== Trial 2 ===")
print(df_trial2.head())
'''
# Out:
# Sheets found: ['Trial1', 'Trial2', 'Trial3', 'Trial4', 'Trial5', 'Trial6', 'Trial7', 'Trial8', 'Trial9', 'Trial10', 'Trial11']
# '\nprint("=== Trial 1 ===")\nprint(df_trial1.head())\n\nprint("=== Trial 2 ===")\nprint(df_trial2.head())\n'

# %%
print("=== Trial 11 ===")
print(df_trial11.head())
# Out:
# === Trial 11 ===
#    PlotID Replication Treatment Name of plot        Date  Plant height (cm)  \
# 0       1          R1        T1         R1T1  09/02/2024               22.1
# 1       2          R1        T2         R1T2  09/02/2024               21.1
# 2       3          R1        T3         R1T3  09/02/2024               22.2
# 3       4          R1        T4         R1T4  09/02/2024               24.5
# 4       5          R1        T5         R1T5  09/02/2024               20.6
#
#    Leaf length(cm)  Psudostem Length(cm)  Number of leaves  \
# 0             19.4                   3.0                 4
# 1             17.3                   3.5                 4
# 2             20.1                   3.5                 4
# 3             21.4                   3.0                 4
# 4             17.1                   2.5                 4
#
#    Psuetostem width(cm)  Leaf width(cm)
# 0                  4.89            3.92
# 1                  4.35            3.96
# ...

# %%
# Access a specific column (e.g., 'ColumnName')
column = df_trial11.iloc[:, 0]

# Count total non-null values in the column
count = column.count()
print (count)
# Out:
# 105

# %%
# Append a new column after the last column

# Array 
import numpy as np

#new_column_values = np.ones(count)

# Get the last column name
last_col_name = "pdi_blight_new"

# Create new column values: value + "_" + column name
new_column_values = np.ones(count)

# Append as a new column
df_trial11[f"{last_col_name}"] = new_column_values

# Save to a new Excel file (optional)
#df.to_excel("modified_file.xlsx", index=False)

# Preview
print(df_trial11.head())
# Out:
#    PlotID Replication Treatment Name of plot        Date  Plant height (cm)  \
# 0       1          R1        T1         R1T1  09/02/2024               22.1
# 1       2          R1        T2         R1T2  09/02/2024               21.1
# 2       3          R1        T3         R1T3  09/02/2024               22.2
# 3       4          R1        T4         R1T4  09/02/2024               24.5
# 4       5          R1        T5         R1T5  09/02/2024               20.6
#
#    Leaf length(cm)  Psudostem Length(cm)  Number of leaves  \
# 0             19.4                   3.0                 4
# 1             17.3                   3.5                 4
# 2             20.1                   3.5                 4
# 3             21.4                   3.0                 4
# 4             17.1                   2.5                 4
#
#    Psuetostem width(cm)  Leaf width(cm)  pdi_blight_new
# 0                  4.89            3.92             1.0
# ...

# %% [markdown]
# # Write the updated columns into the master excel sheet

# %%
from openpyxl import load_workbook
with pd.ExcelWriter("MASTER_DF_updated.xlsx", engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
    df_trial11.to_excel(writer, sheet_name='Sheet11', index=False)
