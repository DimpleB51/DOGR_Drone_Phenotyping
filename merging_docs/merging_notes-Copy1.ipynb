# %%
import pandas as pd

# PDI data
df_pdi = pd.read_csv('pdi_data.csv')
#print (df_pdi.head())

# %%
# Thrips data
df_th = pd.read_csv('thrips_data.csv')
#print (df_th.head())

# %%
import pandas as pd

# Read all sheets from the Excel file into a dictionary
xls = pd.read_excel('MASTER_DF_updated.xlsx', sheet_name=None)

# View all available sheet names
sheet_names = list(xls.keys())
print("Sheets found:", sheet_names)

# Access each sheet individually for separate use

df_trial1 = xls.get('Trial1')
df_trial2 = xls.get('Trial2')
df_trial3 = xls.get('Trial3')
df_trial4 = xls.get('Trial4')
df_trial5 = xls.get('Trial5')
df_trial6 = xls.get('Trial6')
df_trial7 = xls.get('Trial7')
df_trial8 = xls.get('Trial8')
df_trial9 = xls.get('Trial9')
df_trial10 = xls.get('Trial10')
df_trial11 = xls.get('Trial11')

# Example: print the first few rows of each trial
'''
print("=== Trial 1 ===")
print(df_trial1.head())

print("=== Trial 2 ===")
print(df_trial2.head())
'''
# Out:
# Sheets found: ['Trial1', 'Trial2', 'Trial3', 'Trial4', 'Trial5', 'Trial6', 'Trial7', 'Trial8', 'Trial9', 'Trial10', 'Trial11']
# '\nprint("=== Trial 1 ===")\nprint(df_trial1.head())\n\nprint("=== Trial 2 ===")\nprint(df_trial2.head())\n'

# %%
dates=df['Date']
print (dates.head())
# Out:
# 0    03.11.2023
# 1    03.11.2023
# 2    03.11.2023
# 3    03.11.2023
# 4    03.11.2023
# Name: Date, dtype: object

# %%
dates_list = df['Date'].tolist()

# %%
unique_dates = df['Date'].unique()
unique_dates_list = unique_dates.tolist()
print (unique_dates_list)
# Out:
# ['03.11.2023', '07.11.2023', '10.11.2023', '12.10.2023', '14.09.2023', '17.10.2023', '17.11.2023', '18.09.2023', '20.10.2023', '21.09.2023', '21.11.2023', '23.10.2023', '24.11.2023', '25.09.2023', '27.10.2023', '31.10.2023', '01.12.2023', '05.12.2023', '08.12.2023', '1.12.2023', '12.12.2023', '13.10.2023', '15.12.2023', '19.12.2023', '3.11.2023', '5.12.2023', '7.11.2023', '02.01.2024', '05.01.2024', '22.12.2023', '26.12.2023', '29.11.2023', '29.12.2023', '02.02.2024', '06.02.2024', '09.01.2024', '09.02.2024', '12.01.2024', '13.02.2024', '16.01.2024', '16.02.2024', '19.01.2024', '20.02.2024', '23.01.2024', '27.01.2024', '30.01.2024', '01.03.2024', '05.03.2024', '08.03.2024', '12.03.2024', '15.03.2024', '23.02.2024', '27.02.2024']

# %%
from datetime import datetime
# Step 1: Convert strings to datetime objects
date_objects = [datetime.strptime(date, '%d.%m.%Y') for date in unique_dates_list]

# Step 2: Sort the datetime objects
sorted_dates = sorted(date_objects)

# Step 3 (optional): Convert back to string format
sorted_date_strings = [date.strftime('%d.%m.%Y') for date in sorted_dates]

print(sorted_date_strings)
# Out:
# ['14.09.2023', '18.09.2023', '21.09.2023', '25.09.2023', '12.10.2023', '13.10.2023', '17.10.2023', '20.10.2023', '23.10.2023', '27.10.2023', '31.10.2023', '03.11.2023', '03.11.2023', '07.11.2023', '07.11.2023', '10.11.2023', '17.11.2023', '21.11.2023', '24.11.2023', '29.11.2023', '01.12.2023', '01.12.2023', '05.12.2023', '05.12.2023', '08.12.2023', '12.12.2023', '15.12.2023', '19.12.2023', '22.12.2023', '26.12.2023', '29.12.2023', '02.01.2024', '05.01.2024', '09.01.2024', '12.01.2024', '16.01.2024', '19.01.2024', '23.01.2024', '27.01.2024', '30.01.2024', '02.02.2024', '06.02.2024', '09.02.2024', '13.02.2024', '16.02.2024', '20.02.2024', '23.02.2024', '27.02.2024', '01.03.2024', '05.03.2024', '08.03.2024', '12.03.2024', '15.03.2024']
